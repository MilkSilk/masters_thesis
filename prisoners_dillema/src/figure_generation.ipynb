# %%
import matplotlib.pyplot as plt

from prisoner.learning_prisoner import LearningPrisoner
from runner import main

# %%
new_prisoner = LearningPrisoner()
learning_rates = []
for i in range(10_000):
    new_prisoner.update_learning_rate()
    learning_rates.append(new_prisoner.learning_rate)
    new_prisoner.episode_index += 1
learning_rates[:5],"" ,"...", "", learning_rates[-5:]
# Out:
# ([1.0,
#   0.5946035575013605,
#   0.43869133765083085,
#   0.35355339059327373,
#   0.2990697562442441],
#  '',
#  '...',
#  '',
#  [0.0010003001050385145,
#   0.0010002250590787467,
#   0.0010001500262548134,
#   0.0010000750065631016,
#   0.001])

# %%
plt.plot(learning_rates[:100])
plt.plot([0, 100], [0.001, 0.001], linestyle="--", color="red")
plt.title("Tempo uczenia przez pierwsze 100 epizodów")
# plt.savefig("first_100_episodes_lr.png")
# Out:
# Text(0.5, 1.0, 'Tempo uczenia przez pierwsze 100 epizodów')

# %%
plt.plot(learning_rates)
plt.plot([0, 10_000], [0.001, 0.001], linestyle="--", color="red")
plt.title("Tempo uczenia przez wszystkie epizody")
# plt.savefig("all_episodes_lr.png")
# Out:
# Text(0.5, 1.0, 'Tempo uczenia przez wszystkie epizody')

# %%
main.run_q_learning_experiment()
# Out:
# {'average': [0.4376242322933353, 1.0666862383843314], 'std_dev': [0.11304722021328822, 0.007227113142750725], 'min': [0.046527793952181686, 1.0498841227589428], 'max': [0.5815115124758296, 1.083969092686711]}
# ...

# %%
q_tables = [[0.47115686709491017, 1.0700226802938386], [0.5069587969724585, 1.0689273515710007], [0.5197621623588444, 1.0629429244398567], [0.4095946290388983, 1.077011767278334], [0.565202092521169, 1.068305375732237], [0.565043941807604, 1.0696808688944721], [0.4201787631389622, 1.0752747693958695], [0.44044633887699663, 1.0675045915617893], [0.39317161847290205, 1.0688274427322664], [0.5281360192283652, 1.0600693124079703], [0.27839299761474406, 1.0639363353194946], [0.4898506971031737, 1.0618844823539477], [0.436175947044016, 1.0539818997850747], [0.5299374025452526, 1.0584582406473144], [0.5494580414583611, 1.0791762201127357], [0.5344226238101077, 1.069554185991079], [0.5283728126328153, 1.066877038360467], [0.4153421364942873, 1.064847727820231], [0.34403164902312056, 1.0684611885365616], [0.48469252053244755, 1.071028959833628], [0.5327093117945377, 1.0621923206396138], [0.43041156175428336, 1.062508785462651], [0.47022286956844195, 1.082811715041889], [0.44893396156037746, 1.0569994895193493], [0.26515393759676925, 1.066789795553487], [0.2984176603785357, 1.0666701391494935], [0.22217393435822155, 1.0530783402642956], [0.5789759015965883, 1.0669476673879656], [0.41612613266320586, 1.0677677115539312], [0.3512784118417982, 1.0547953878904182], [0.48639070161220127, 1.0634495143133247], [0.4117845149649673, 1.0617719689371952], [0.5198075251209174, 1.0681116369014578], [0.5197458619459112, 1.0600986952618707], [0.4984762939272776, 1.069144824579398], [0.4384954101512403, 1.068132263474319], [0.3400162005788664, 1.063487561828196], [0.3876380639648881, 1.0756695482821959], [0.046527793952181686, 1.0636991141202], [0.532646328980935, 1.0669354